# %% [markdown]
# # Tasca 3
# ##### Bernat Puig Casals
# ##### 18/11/2025
# ### Exercici 3 - Trimestres 2
# #### Demanarem quin trimestre mostrar.

# %%
trimestres = {
    1: ["Gener", "Febrer", "Març"],
    2: ["Abril", "Maig", "Juny"],
    3: ["Juliol", "Agost", "Septembre"],
    4: ["Octubre", "Novembre", "Desembre"]
  }

posicions = [1, 2, 3, 4]
pos = 0
while pos not in posicions:
    pos = 0
    print("1 -> Trimestre 1")
    print("2 -> Trimestre 2")
    print("3 -> Trimestre 3")
    print("4 -> Trimestre 4")
    pos = int(input("Digues un numero dels anteriors: "))
    if pos == 1:
      tri = 1
    elif pos == 2:
      tri = 2
    elif pos == 3:
      tri = 3
    elif pos == 4:
      tri = 4
    print(f"\nTrimestre: {tri}")
    print(f"{trimestres[tri][:]}")
# Out:
# 1 -> Trimestre 1
# 2 -> Trimestre 2
# 3 -> Trimestre 3
# 4 -> Trimestre 4
#
# Trimestre: 2
# ['Abril', 'Maig', 'Juny']
