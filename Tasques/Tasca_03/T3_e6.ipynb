# %% [markdown]
# # Tasca 3
# ##### Bernat Puig Casals
# ##### 18/11/2025
# ### Exercici 6 - Setmana
# #### Creem una tupla amb els dies de la setmana, expliquem sobre tuples (immutable), mostrem dies setmana sense repetits festius.

# %%
tupla = ("Dilluns", "Dimarts", "Dimecres", "Dijous", "Divendres", "Dissabte", "Diumenje")

print(f"Les tuples no poden ser modificades sense recrear-les.")
try:
    tupla[7]="Hola"
except:
    print("Algo no ha anat be")
print(tupla)

festius = {"Dissabte", "Diumenje"}

print(set(tupla) - festius)
# Out:
# Les tuples no poden ser modificades sense recrear-les.
# Algo no ha anat be
# ('Dilluns', 'Dimarts', 'Dimecres', 'Dijous', 'Divendres', 'Dissabte', 'Diumenje')
# {'Divendres', 'Dijous', 'Dilluns', 'Dimecres', 'Dimarts'}
# {1, 5, 10, 15, 20}
